# %% [markdown]
# # Phase 3
#
# 1) Now make only 1 data frame of two CSV files using the join operation of pandas and start doing EDA.
#
# 2) Do the complete EDA in detail to explore the insights of data and write detailed observations of each analysis.
#
#
#
# # Phase 4
#
# 1) Write the complete Machine learning code to make predictions of votes and gross collection. Use appropriate models on their label basis. Remember you need to make 2 different predictions: vote and gross collection.
#
# 2) Apply all the best techniques of scaling, and hyperparameter tuning, and avoid underfitting or overfitting (bias/variance)
#
# 3) At the end save the best model and convey on which basis you have chosen that model.

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # GETTING THE FIRST DATA SET

# %%
df1=pd.read_csv('movie1.csv')
df1.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                                          Inception  Christopher Nolan
# 3    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4    5              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore
# 0       None               152  2008                9.0         84
# 1       None               201  2003                9.0         94
# 2       None               148  2010                8.8         74
# 3       None               178  2001                8.8         92
# 4       None               179  2002                8.8         87

# %% [markdown]
# # EDA OF FIRST DATASET

# %%
df1.shape
# Out:
# (1551, 8)

# %%
df1.columns
# Out:
# Index(['Sno', 'Movie_Name', 'Director_1', 'Director_2', 'Duration_in_mins',
#        'year', 'ratings_out_of_10', 'Metascore'],
#       dtype='object')

# %% [markdown]
# # GETTING THE SECOND DATASET

# %%
df2=pd.read_csv('movie2.csv')
df2.head()
# Out:
#                                           Movie_Name               star_1  \
# 0                                    The Dark Knight       Christian Bale
# 1      The Lord of the Rings: The Return of the King          Elijah Wood
# 2                                          Inception    Leonardo DiCaprio
# 3  The Lord of the Rings: The Fellowship of the Ring          Elijah Wood
# 4              The Lord of the Rings: The Two Towers          Elijah Wood
#
#                  star_2           star_3          star_4    votes Genre_1  \
# 0          Heath Ledger    Aaron Eckhart   Michael Caine  2717521  Action
# 1       Viggo Mortensen     Ian McKellen   Orlando Bloom  1886645  Action
# 2  Joseph Gordon-Levitt      Elliot Page    Ken Watanabe  2412332  Action
# 3          Ian McKellen    Orlando Bloom       Sean Bean  1915355  Action
# 4          Ian McKellen  Viggo Mortensen   Orlando Bloom  1702927  Action
#
#       Genre_2  Genre_3 Gross_collection Certification
# ...

# %% [markdown]
# # EDA OF SECOND DATASET

# %%
df2.shape
# Out:
# (1551, 11)

# %%
df2.columns
# Out:
# Index(['Movie_Name', 'star_1', 'star_2', 'star_3', 'star_4', 'votes',
#        'Genre_1', 'Genre_2', 'Genre_3', 'Gross_collection', 'Certification'],
#       dtype='object')

# %% [markdown]
# # MERGING BOTH DATASETS

# %%
dfnew=df1.merge(df2)
dfnew.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                                          Inception  Christopher Nolan
# 3    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4    5              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore  \
# 0       None               152  2008                9.0         84
# 1       None               201  2003                9.0         94
# 2       None               148  2010                8.8         74
# 3       None               178  2001                8.8         92
# 4       None               179  2002                8.8         87
#
#                 star_1                star_2           star_3          star_4  \
# ...

# %% [markdown]
# # EDA OF MERGED DATASET

# %%
dfnew.shape
# Out:
# (1579, 18)

# %%
dfnew.columns
# Out:
# Index(['Sno', 'Movie_Name', 'Director_1', 'Director_2', 'Duration_in_mins',
#        'year', 'ratings_out_of_10', 'Metascore', 'star_1', 'star_2', 'star_3',
#        'star_4', 'votes', 'Genre_1', 'Genre_2', 'Genre_3', 'Gross_collection',
#        'Certification'],
#       dtype='object')

# %%
dfnew.dtypes
# Out:
# Sno                    int64
# Movie_Name            object
# Director_1            object
# Director_2            object
# Duration_in_mins       int64
# year                   int64
# ratings_out_of_10    float64
# Metascore              int64
# star_1                object
# star_2                object
# star_3                object
# star_4                object
# votes                  int64
# Genre_1               object
# Genre_2               object
# Genre_3               object
# Gross_collection      object
# Certification         object
# dtype: object

# %%
dfnew.isnull().sum()
# Out:
# Sno                  0
# Movie_Name           0
# Director_1           0
# Director_2           0
# Duration_in_mins     0
# year                 0
# ratings_out_of_10    0
# Metascore            0
# star_1               0
# star_2               0
# star_3               0
# star_4               0
# votes                0
# Genre_1              0
# Genre_2              0
# Genre_3              0
# Gross_collection     0
# Certification        0
# dtype: int64

# %%
dfnew['votes']
# Out:
# 0       2717521
# 1       1886645
# 2       2412332
# 3       1915355
# 4       1702927
#          ...
# 1574      29633
# 1575      35148
# 1576      45103
# 1577     121053
# 1578      37979
# Name: votes, Length: 1579, dtype: int64

# %%
dfnew['Gross_collection']
# Out:
# 0       534.86
# 1       377.85
# 2       292.58
# 3       315.54
# 4       342.55
#          ...
# 1574         0
# 1575         0
# 1576         0
# 1577     31.15
# 1578     44.54
# Name: Gross_collection, Length: 1579, dtype: object

# %%
dfnew.columns
# Out:
# Index(['Sno', 'Movie_Name', 'Director_1', 'Director_2', 'Duration_in_mins',
#        'year', 'ratings_out_of_10', 'Metascore', 'star_1', 'star_2', 'star_3',
#        'star_4', 'votes', 'Genre_1', 'Genre_2', 'Genre_3', 'Gross_collection',
#        'Certification'],
#       dtype='object')

# %% [markdown]
# # DROPPING DUPLICATES

# %%
dfnew['Sno'].duplicated().sum()
# Out:
# 32

# %%
dfnew['Movie_Name'].duplicated().sum()
# Out:
# 48

# %%
dfnew['Director_1'].duplicated().sum()
# Out:
# 730

# %%
dfnew['Director_2'].duplicated().sum()
# Out:
# 1482

# %%
dfnew['Duration_in_mins'].duplicated().sum()
# Out:
# 1463

# %%
dfnew['year'].duplicated().sum()
# Out:
# 1505

# %%
dfnew['ratings_out_of_10'].duplicated().sum()
# Out:
# 1543

# %%
dfnew['Metascore'].duplicated().sum()
# Out:
# 1495

# %%
dfnew['star_1'].duplicated().sum()
# Out:
# 921

# %%
dfnew['star_2'].duplicated().sum()
# Out:
# 526

# %%
dfnew['star_3'].duplicated().sum()
# Out:
# 388

# %%
dfnew['star_4'].duplicated().sum()
# Out:
# 300

# %%
dfnew['votes'].duplicated().sum()
# Out:
# 37

# %%
dfnew['Genre_1'].duplicated().sum()
# Out:
# 1577

# %%
dfnew['Genre_2'].duplicated().sum()
# Out:
# 1563

# %%
dfnew['Genre_3'].duplicated().sum()
# Out:
# 1561

# %%
dfnew['Gross_collection'].duplicated().sum()
# Out:
# 366

# %%
dfnew['Certification'].duplicated().sum()
# Out:
# 1563

# %%
dfnew1=dfnew.drop_duplicates()
dfnew1.head()
# Out:
#    Sno                                         Movie_Name          Director_1  \
# 0    1                                    The Dark Knight  Christopher Nolan
# 1    2      The Lord of the Rings: The Return of the King      Peter Jackson
# 2    3                                          Inception  Christopher Nolan
# 3    4  The Lord of the Rings: The Fellowship of the Ring      Peter Jackson
# 4    5              The Lord of the Rings: The Two Towers      Peter Jackson
#
#   Director_2  Duration_in_mins  year  ratings_out_of_10  Metascore  \
# 0       None               152  2008                9.0         84
# 1       None               201  2003                9.0         94
# 2       None               148  2010                8.8         74
# 3       None               178  2001                8.8         92
# 4       None               179  2002                8.8         87
#
#                 star_1                star_2           star_3          star_4  \
# ...

# %%
dfnew1.shape
# Out:
# (1579, 18)

# %% [markdown]
# # CHECKING FOR NULL DATAS

# %%
dfnew1.isnull().sum()
# Out:
# Sno                  0
# Movie_Name           0
# Director_1           0
# Director_2           0
# Duration_in_mins     0
# year                 0
# ratings_out_of_10    0
# Metascore            0
# star_1               0
# star_2               0
# star_3               0
# star_4               0
# votes                0
# Genre_1              0
# Genre_2              0
# Genre_3              0
# Gross_collection     0
# Certification        0
# dtype: int64

# %%
dfnew1.dtypes
# Out:
# Sno                    int64
# Movie_Name            object
# Director_1            object
# Director_2            object
# Duration_in_mins       int64
# year                   int64
# ratings_out_of_10    float64
# Metascore              int64
# star_1                object
# star_2                object
# star_3                object
# star_4                object
# votes                  int64
# Genre_1               object
# Genre_2               object
# Genre_3               object
# Gross_collection      object
# Certification         object
# dtype: object

# %% [markdown]
# # CONVERTING OBJECT DATAS INTO FLOAT DATA OR INT DATA

# %%
from sklearn.preprocessing import OrdinalEncoder
ordin=OrdinalEncoder()

# %%
for i in dfnew1.columns:
    if dfnew1[i].dtypes=='object':
        dfnew1[i]=ordin.fit_transform(dfnew1[i].values.reshape(-1,1))

# %%
dfnew1.dtypes
# Out:
# Sno                    int64
# Movie_Name           float64
# Director_1           float64
# Director_2           float64
# Duration_in_mins       int64
# year                   int64
# ratings_out_of_10    float64
# Metascore              int64
# star_1               float64
# star_2               float64
# star_3               float64
# star_4               float64
# votes                  int64
# Genre_1              float64
# Genre_2              float64
# Genre_3              float64
# Gross_collection     float64
# Certification        float64
# dtype: object

# %% [markdown]
# # CONVERTING INTIGER DATA TO FLOAT DATA AS IT DOMINATES MORE IN THE DATASET

# %%
for i in dfnew1.columns:
    if dfnew1[i].dtypes=='int64':
        dfnew1[i]=dfnew1[i].astype('float')

# %%
dfnew1.dtypes
# Out:
# Sno                  float64
# Movie_Name           float64
# Director_1           float64
# Director_2           float64
# Duration_in_mins     float64
# year                 float64
# ratings_out_of_10    float64
# Metascore            float64
# star_1               float64
# star_2               float64
# star_3               float64
# star_4               float64
# votes                float64
# Genre_1              float64
# Genre_2              float64
# Genre_3              float64
# Gross_collection     float64
# Certification        float64
# dtype: object

# %%
dfnew1.isnull().sum()
# Out:
# Sno                  0
# Movie_Name           0
# Director_1           0
# Director_2           0
# Duration_in_mins     0
# year                 0
# ratings_out_of_10    0
# Metascore            0
# star_1               0
# star_2               0
# star_3               0
# star_4               0
# votes                0
# Genre_1              0
# Genre_2              0
# Genre_3              0
# Gross_collection     0
# Certification        0
# dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
collist=dfnew1.columns.values
ncol=50
nrows=50
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1) 
    sns.boxplot(dfnew1[collist[i]],color='green')
    plt.tight_layout()

# %% [markdown]
# THE ABOVE GIVES A CLEAR PICTURE OF THE DISTRIBUTION OF THE DATASET

# %%
sns.histplot(data=dfnew1,bins=20)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS HIST DISTRIBUTION OF THE DATASET

# %%
sns.jointplot(data=dfnew1,x='Director_1',y='Director_2',hue='Movie_Name')

# %% [markdown]
#  THE ABOVE SHOWS THE JOINT OF DIRECTOR_1, DIRECTOR_2 AND MOVIE_NAME

# %%
sns.catplot(data=dfnew1,x='Duration_in_mins',y='year')

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF DURATION_IN_MINS AND YEAR

# %%
sns.boxplot(data=dfnew1,x='ratings_out_of_10',y='Metascore')
# Out:
# <AxesSubplot:xlabel='ratings_out_of_10', ylabel='Metascore'>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF RATINGS_OUT_OF_10 AND METASCORE

# %%
plt.bar(dfnew1['star_1'],dfnew1['star_2'])
# Out:
# <BarContainer object of 1579 artists>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF STAR_1 AND STAR_2

# %%
plt.figure(figsize=(10,5))
sns.histplot(dfnew1['star_3'], bins=30)
# Out:
# <AxesSubplot:xlabel='star_3', ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS THE HIST DISTRIBUTION OF STAR_3

# %%
plt.figure(figsize=(10,5))
sns.histplot(dfnew1['star_4'], bins=20)
# Out:
# <AxesSubplot:xlabel='star_4', ylabel='Count'>

# %% [markdown]
# THE ABOVE SHOWS THE HIST FISTRIBUTION OF STAR_4

# %%
sns.violinplot(dfnew1['votes'])
# Out:
# <AxesSubplot:xlabel='votes'>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF VOTES

# %%
sns.violinplot(dfnew1['Gross_collection'])
# Out:
# <AxesSubplot:xlabel='Gross_collection'>

# %% [markdown]
#  THE ABOVE SHOWS THE DISTRIBUTION OF GROSS_COLLECTION

# %%
sns.histplot(data=dfnew1,x='Gross_collection',y='votes',color='red')
# Out:
# <AxesSubplot:xlabel='Gross_collection', ylabel='votes'>

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF GROSS_COLLECTION AND VOTES

# %%
sns.displot(dfnew1['Certification'],kde=True)

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF CERTIFICATION

# %%
dfnew1.plot(figsize=(18,12),kind='density',subplots=True,layout=(2,10),legend=True,sharex=False ) 
plt.show()

# %% [markdown]
# THE ABOVE SHOWS THE DISTRIBUTION OF COMPLETE DATASET DENSITY WISE

# %%
dfnew1.plot(kind='box',subplots=True,layout=(2,10))
# Out:
# Sno                     AxesSubplot(0.125,0.536818;0.065678x0.343182)
# Movie_Name           AxesSubplot(0.203814,0.536818;0.065678x0.343182)
# Director_1           AxesSubplot(0.282627,0.536818;0.065678x0.343182)
# Director_2           AxesSubplot(0.361441,0.536818;0.065678x0.343182)
# Duration_in_mins     AxesSubplot(0.440254,0.536818;0.065678x0.343182)
# year                 AxesSubplot(0.519068,0.536818;0.065678x0.343182)
# ratings_out_of_10    AxesSubplot(0.597881,0.536818;0.065678x0.343182)
# Metascore            AxesSubplot(0.676695,0.536818;0.065678x0.343182)
# star_1               AxesSubplot(0.755508,0.536818;0.065678x0.343182)
# star_2               AxesSubplot(0.834322,0.536818;0.065678x0.343182)
# star_3                     AxesSubplot(0.125,0.125;0.065678x0.343182)
# star_4                  AxesSubplot(0.203814,0.125;0.065678x0.343182)
# votes                   AxesSubplot(0.282627,0.125;0.065678x0.343182)
# ...

# %% [markdown]
# THE ABOVE CLEARLY STATES THE PRESENCE OF OUTLIERS IN SOME COLUMNS

# %%
sns.countplot(dfnew1['votes'])
# Out:
# <AxesSubplot:xlabel='votes', ylabel='count'>

# %% [markdown]
# THE ABOVE SHOWS THE COUNT OF VOTES COLUMN

# %%
sns.countplot(dfnew1['Gross_collection'])
# Out:
# <AxesSubplot:xlabel='Gross_collection', ylabel='count'>

# %% [markdown]
# THE ABOVE GIVES THE DISTRIBUTION OF GROSS_COLLECTION

# %% [markdown]
# # MORE EDA

# %%
dfnew1.describe()
# Out:
#                Sno   Movie_Name   Director_1   Director_2  Duration_in_mins  \
# count  1579.000000  1579.000000  1579.000000  1579.000000       1579.000000
# mean    776.070298   766.181761   456.720076    67.528816        116.395820
# std     447.663251   442.003181   236.215585     9.065088         21.709536
# min       1.000000     0.000000     0.000000     0.000000         45.000000
# 25%     388.500000   382.500000   264.500000    69.000000        101.000000
# 50%     776.000000   768.000000   454.000000    69.000000        113.000000
# 75%    1163.500000  1150.500000   666.000000    69.000000        128.000000
# max    1551.000000  1530.000000   848.000000    96.000000        321.000000
#
#               year  ratings_out_of_10    Metascore       star_1       star_2  \
# count  1579.000000        1579.000000  1579.000000  1579.000000  1579.000000
# mean   2005.730842           6.710703    53.618746   325.882204   531.939835
# ...

# %% [markdown]
# THE ABOVE SHOWS SOME MILDLY SKEWED DATAS THAT TOO MOSTLY BY THE RIGHT

# %%
dfnew1.corr()
# Out:
#                         Sno  Movie_Name  Director_1  Director_2  \
# Sno                1.000000    0.012624    0.016138    0.026540
# Movie_Name         0.012624    1.000000   -0.000152    0.035978
# Director_1         0.016138   -0.000152    1.000000    0.231353
# Director_2         0.026540    0.035978    0.231353    1.000000
# Duration_in_mins  -0.364340    0.006984    0.040050    0.035201
# year               0.151639   -0.043088   -0.058389   -0.006934
# ratings_out_of_10 -0.983394   -0.013675   -0.015114   -0.028228
# Metascore         -0.749542   -0.024520   -0.015167   -0.034621
# star_1            -0.042125    0.002296    0.027831    0.040072
# star_2            -0.028964   -0.009248    0.028060   -0.018359
# star_3            -0.031260    0.003677    0.013028    0.076054
# star_4            -0.062111   -0.003167    0.012836   -0.018414
# votes             -0.405984    0.020736   -0.016082   -0.017527
# Genre_1           -0.113731   -0.020096   -0.127844   -0.095000
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(dfnew1.corr(),annot=True)
plt.show()

# %%
dfnew1.skew()
# Out:
# Sno                 -0.001366
# Movie_Name          -0.003199
# Director_1          -0.121246
# Director_2          -5.017166
# Duration_in_mins     1.488324
# year                -1.477393
# ratings_out_of_10    0.438321
# Metascore            0.096051
# star_1               0.052827
# star_2              -0.000802
# star_3               0.054385
# star_4               0.021154
# votes                3.642502
# Genre_1              4.506014
# Genre_2              1.575750
# Genre_3              0.165163
# Gross_collection     0.206297
# Certification       -0.321329
# dtype: float64

# %% [markdown]
# MOST OF THE SKEW IS REMOVED EXCEPT FOR DIRECTOR_2 COLUMNS OF WHICH IT CAN BE REMOVED DUE TO HEAVILY SKEWED DATAS

# %%
dfnew2=dfnew1.drop(['Director_2'],axis=1)

# %% [markdown]
# # REMOVING OUTLIERS

# %%
from scipy.stats import zscore
z=np.abs(zscore(dfnew1))

# %%
new=dfnew1[(z<3).all(axis=1)]
new.head()
# Out:
#        Sno  Movie_Name  Director_1  Director_2  Duration_in_mins    year  \
# 7      8.0      1004.0       776.0        69.0             153.0  2020.0
# 18    20.0       786.0       609.0        69.0             101.0  2003.0
# 19    20.0       786.0       609.0        69.0             101.0  2003.0
# 20  1365.0       786.0       753.0        69.0             104.0  2013.0
# 21  1365.0       786.0       753.0        69.0             104.0  2013.0
#
#     ratings_out_of_10  Metascore  star_1  star_2  star_3  star_4     votes  \
# 7                 8.7       90.0   576.0   777.0    83.0  1203.0  119469.0
# 18                8.4       84.0   101.0  1031.0   571.0   656.0  596202.0
# 19                8.4       84.0   307.0   283.0   995.0  1085.0   78216.0
# 20                5.8       31.0   101.0  1031.0   571.0   656.0  596202.0
# 21                5.8       31.0   307.0   283.0   995.0  1085.0   78216.0
#
#     Genre_1  Genre_2  Genre_3  Gross_collection  Certification
# ...

# %%
new.skew()
# Out:
# Sno                 -0.051181
# Movie_Name          -0.003826
# Director_1          -0.135556
# Director_2          -2.635626
# Duration_in_mins     0.730937
# year                -0.972825
# ratings_out_of_10    0.394510
# Metascore            0.106366
# star_1               0.032944
# star_2               0.005222
# star_3               0.031473
# star_4               0.052957
# votes                1.769687
# Genre_1              0.000000
# Genre_2              1.301236
# Genre_3              0.173045
# Gross_collection     0.178515
# Certification       -0.189860
# dtype: float64

# %%
new.shape
# Out:
# (1327, 18)

# %%
collist=new.columns.values
ncol=50
nrows=50
plt.figure(figsize=(ncol,3*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1) 
    sns.boxplot(new[collist[i]],color='blue')
    plt.tight_layout()

# %% [markdown]
# # FIRST PREDICTION -- VOTES

# %% [markdown]
# # SPLITTING X AND Y

# %%
x=new.drop('votes',axis=1)
y=new['votes']

# %%
x.shape
# Out:
# (1327, 17)

# %%
y.shape
# Out:
# (1327,)

# %% [markdown]
# # TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxR2=0
maxRS=0
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    score=r2_score(y_test,predlr)
    print('R2_score of LinearRegression ' ,score, 'at random_state ' ,i)
    if score > maxR2:
        maxR2=score
        maxRS=i
    print('R2 score of lr ' ,maxR2*100, 'at random_state ' ,maxRS)
# Out:
# R2_score of LinearRegression  0.3621121693946179 at random_state  0
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.26770267413340265 at random_state  1
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.2840131422709039 at random_state  2
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.2603046826125398 at random_state  3
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.2559361685492504 at random_state  4
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.2791144617889496 at random_state  5
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.25068967534263087 at random_state  6
# R2 score of lr  36.211216939461785 at random_state  0
# R2_score of LinearRegression  0.2658790132615534 at random_state  7
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=19)
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)
score=r2_score(predlr,y_test)
print('R2_score of LinearRegression ' ,score*100)
print(mean_absolute_error(predlr,y_test))
print((mean_squared_error(predlr,y_test)))
# Out:
# R2_score of LinearRegression  -89.41357484185943
# 97392.26843212394
# 18795053270.50998

# %% [markdown]
# # TESTING MORE MODELS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
knr=KNeighborsRegressor()
gbr=GradientBoostingRegressor()
abr=AdaBoostRegressor()
etr=ExtraTreesRegressor()
rfr=RandomForestRegressor()
dtr=DecisionTreeRegressor()
svr=SVR()

# %%
model=[knr,gbr,abr,etr,rfr,dtr,svr]
for i in model:
    i.fit(x_train,y_train)
    predi=i.predict(x_test)
    print('R2_score of model ' , i ,'is = ' ,r2_score(y_test,predi)*100)
# Out:
# R2_score of model  KNeighborsRegressor() is =  17.738938762195467
# R2_score of model  GradientBoostingRegressor() is =  67.96142163729463
# R2_score of model  AdaBoostRegressor() is =  40.78358208841442
# R2_score of model  ExtraTreesRegressor() is =  66.40150600830701
# R2_score of model  RandomForestRegressor() is =  64.3710598519918
# R2_score of model  DecisionTreeRegressor() is =  20.040940303567744
# R2_score of model  SVR() is =  -11.010689313315346

# %% [markdown]
# # CROSS_VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,10):
    models=[lr,knr,gbr,abr,etr,rfr,dtr,svr]
    for j in models:
        j.fit(x_train,y_train)
        predj=j.predict(x_test)
        score=r2_score(y_test,predj)
        cross=cross_val_score(j,x_train,y_train,cv=i)
        print('R2_score of model ' ,j, 'is equal = ', score*100)
        print('Cross validation of model ',i, 'is equal = ',cross.mean())
        print('Diff between r2_score and cross_validation of model ' ,j,'is equal = ',score-cross.mean())
# Out:
# R2_score of model  LinearRegression() is equal =  38.83109315080701
# Cross validation of model  2 is equal =  0.20360714430248378
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.18470378720558628
# R2_score of model  KNeighborsRegressor() is equal =  17.738938762195467
# Cross validation of model  2 is equal =  0.11208765043488494
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.06530173718706972
# R2_score of model  GradientBoostingRegressor() is equal =  67.45104314701645
# Cross validation of model  2 is equal =  0.4961451081986267
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.1783653232715377
# R2_score of model  AdaBoostRegressor() is equal =  47.369670021553354
# Cross validation of model  2 is equal =  0.34272802469752606
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.1309686755180075
# ...

# %% [markdown]
# # REGULARISATION

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet
l=Lasso()
r=Ridge()
en=ElasticNet()

# %%
models=[l,r,en]
for i in models:
    i.fit(x_train,y_train)
    alpha=[0.001,0.001,0.01,0.1,1]
    for j in alpha:
        predmodel=i.predict(x_test)
        print('R2_score : ' ,(r2_score(y_test,predmodel))*100, 'at model ',i,'with alpha ',j)
        print(mean_squared_error(y_test,predmodel))
        print(mean_absolute_error(y_test,predmodel))
# Out:
# R2_score :  38.83093088720258 at model  Lasso() with alpha  0.001
# 18795103128.407497
# 97392.09931999675
# R2_score :  38.83093088720258 at model  Lasso() with alpha  0.001
# 18795103128.407497
# 97392.09931999675
# R2_score :  38.83093088720258 at model  Lasso() with alpha  0.01
# 18795103128.407497
# 97392.09931999675
# R2_score :  38.83093088720258 at model  Lasso() with alpha  0.1
# 18795103128.407497
# 97392.09931999675
# R2_score :  38.83093088720258 at model  Lasso() with alpha  1
# 18795103128.407497
# 97392.09931999675
# R2_score :  38.81608861640152 at model  Ridge() with alpha  0.001
# 18799663636.102184
# 97382.1216349082
# R2_score :  38.81608861640152 at model  Ridge() with alpha  0.001
# 18799663636.102184
# 97382.1216349082
# R2_score :  38.81608861640152 at model  Ridge() with alpha  0.01
# 18799663636.102184
# 97382.1216349082
# R2_score :  38.81608861640152 at model  Ridge() with alpha  0.1
# 18799663636.102184
# 97382.1216349082
# ...

# %% [markdown]
# # HYPERTUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_gbr=GridSearchCV(estimator=gbr,param_grid=parameters)
gscv_gbr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_gbr.best_score_)
print(gscv_gbr.best_params_)
print(gscv_gbr.best_estimator_)
# Out:
# 0.5435102232909138
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'log2', 'n_estimators': 200}
# GradientBoostingRegressor(criterion='squared_error', max_features='log2',
#                           n_estimators=200)

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_etr=GridSearchCV(estimator=etr,param_grid=parameters)
gscv_etr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_etr.best_score_)
print(gscv_etr.best_params_)
print(gscv_etr.best_estimator_)
# Out:
# 0.30465800375994656
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 100}
# ExtraTreesRegressor(max_depth=3, max_features='auto')

# %%
parameters={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_rfr=GridSearchCV(estimator=rfr,param_grid=parameters)
gscv_rfr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_rfr.best_score_)
print(gscv_rfr.best_params_)
print(gscv_rfr.best_estimator_)
# Out:
# 0.37404302209391893
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# RandomForestRegressor(max_depth=3, max_features='auto', n_estimators=200)

# %% [markdown]
# # ROC_CURVE

# %%
from sklearn.metrics import roc_curve,plot_roc_curve

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
predgbr=gbr.predict(x_test)
score=r2_score(predgbr,y_test)
print(score)
# Out:
# 0.42084058367094046

# %%
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
predetr=etr.predict(x_test)
score_a=r2_score(predetr,y_test)
print(score_a)
# Out:
# 0.3376168410113971

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
score_b=r2_score(predrfr,y_test)
print(score_b)
# Out:
# 0.3208061035049199

# %%
plt.scatter(predgbr,predetr,predrfr,y_test)
plt.plot(y_test,y_test,linewidth=4,color='Red')

# %% [markdown]
# # Above all methods of testing GRADIENT BOOSTING REGRESSOR is found to be the most suitable model as it gives the more accurate r2_score for predicting VOTES in the dataset,movie1,so we are saving it.
#
# # SAVING THE BEST FITTED MODEL

# %%
import pickle
filename='movie1_votes.pkl'

# %%
pickle.dump(gbr,open(filename,'wb'))

# %% [markdown]
# # LOADING THE SAVED MODEL

# %%
pickle.load(open(filename,'rb'))
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# # SECOND PREDICTION --- GROSS_COLLECTION

# %% [markdown]
# # SPLITTING X1 AND Y1

# %%
x1=new.drop('Gross_collection',axis=1)
y1=new['Gross_collection']

# %%
x1.shape
# Out:
# (1327, 17)

# %%
y1.shape
# Out:
# (1327,)

# %% [markdown]
# # TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr1=LinearRegression()
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
maxR21=0
maxRS1=0
for i in range(0,1000):
    x_train1,x_test1,y_train1,y_test1=train_test_split(x1,y1,test_size=0.20,random_state=i)
    lr1.fit(x_train1,y_train1)
    predlr1=lr1.predict(x_test1)
    score1=r2_score(y_test1,predlr1)
    print('R2_score of LinearRegression ' ,score1, 'at random_state ' ,i)
    if score1 > maxR21:
        maxR21=score
        maxRS1=i
    print('R2 score of lr1 ' ,maxR21*100, 'at random_state ' ,maxRS1)
# Out:
# R2_score of LinearRegression  0.09388164433067281 at random_state  0
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.0374289032994547 at random_state  1
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.09886740137922445 at random_state  2
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.07872606852555475 at random_state  3
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.12707363802784089 at random_state  4
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.010918613518060005 at random_state  5
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.0910468069057706 at random_state  6
# R2 score of lr1  42.084058367094045 at random_state  0
# R2_score of LinearRegression  0.08300777490404032 at random_state  7
# ...

# %% [markdown]
# # REGULARISATION

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet
l1=Lasso()
r1=Ridge()
en1=ElasticNet()

# %%
models1=[l,r,en]
for i in models1:
    i.fit(x_train1,y_train1)
    alpha1=[0.001,0.001,0.01,0.1,1]
    for j in alpha1:
        predmodel1=i.predict(x_test1)
        print('R2_score : ' ,(r2_score(y_test1,predmodel1))*100, 'at model ',i,'with alpha ',j)
        print(mean_squared_error(y_test1,predmodel1))
        print(mean_absolute_error(y_test1,predmodel1))
# Out:
# R2_score :  11.191573064836557 at model  Lasso() with alpha  0.001
# 133061.14695256477
# 313.90629383174115
# R2_score :  11.191573064836557 at model  Lasso() with alpha  0.001
# 133061.14695256477
# 313.90629383174115
# R2_score :  11.191573064836557 at model  Lasso() with alpha  0.01
# 133061.14695256477
# 313.90629383174115
# R2_score :  11.191573064836557 at model  Lasso() with alpha  0.1
# 133061.14695256477
# 313.90629383174115
# R2_score :  11.191573064836557 at model  Lasso() with alpha  1
# 133061.14695256477
# 313.90629383174115
# R2_score :  11.277329629268163 at model  Ridge() with alpha  0.001
# 132932.6583933618
# 313.27779624389376
# R2_score :  11.277329629268163 at model  Ridge() with alpha  0.001
# 132932.6583933618
# 313.27779624389376
# R2_score :  11.277329629268163 at model  Ridge() with alpha  0.01
# 132932.6583933618
# 313.27779624389376
# R2_score :  11.277329629268163 at model  Ridge() with alpha  0.1
# 132932.6583933618
# 313.27779624389376
# ...

# %% [markdown]
# # TESTING MORE MODELS

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor,RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
knr1=KNeighborsRegressor()
gbr1=GradientBoostingRegressor()
abr1=AdaBoostRegressor()
etr1=ExtraTreesRegressor()
rfr1=RandomForestRegressor()
dtr1=DecisionTreeRegressor()
svr1=SVR()

# %%
model1=[knr1,gbr1,abr1,etr1,rfr1,dtr1,svr1]
for i in model1:
    i.fit(x_train1,y_train1)
    predi1=i.predict(x_test1)
    print('R2_score of model ' , i ,'is = ' ,r2_score(y_test1,predi1)*100)
# Out:
# R2_score of model  KNeighborsRegressor() is =  -3.7005470426761944
# R2_score of model  GradientBoostingRegressor() is =  18.315226627688908
# R2_score of model  AdaBoostRegressor() is =  19.78704207911828
# R2_score of model  ExtraTreesRegressor() is =  19.836205623869375
# R2_score of model  RandomForestRegressor() is =  20.73909879803083
# R2_score of model  DecisionTreeRegressor() is =  -55.378523218744945
# R2_score of model  SVR() is =  0.5220168808357295

# %% [markdown]
# # CROSS_VALIDATION

# %%
from sklearn.model_selection import cross_val_score

# %%
for i in range(2,10):
    models1=[lr1,knr1,gbr1,abr1,etr1,rfr1,dtr1,svr1]
    for j in models1:
        j.fit(x_train1,y_train1)
        predj1=j.predict(x_test1)
        score1=r2_score(y_test1,predj1)
        cross1=cross_val_score(j,x_train1,y_train1,cv=i)
        print('R2_score of model ' ,j, 'is equal = ', score1*100)
        print('Cross validation of model ',i, 'is equal = ',cross1.mean())
        print('Diff between r2_score and cross_validation of model ' ,j,'is equal = ',score1-cross1.mean())
# Out:
# R2_score of model  LinearRegression() is equal =  11.288862322178417
# Cross validation of model  2 is equal =  0.06646552417061924
# Diff between r2_score and cross_validation of model  LinearRegression() is equal =  0.04642309905116493
# R2_score of model  KNeighborsRegressor() is equal =  -3.7005470426761944
# Cross validation of model  2 is equal =  -0.047152957716169897
# Diff between r2_score and cross_validation of model  KNeighborsRegressor() is equal =  0.010147487289407953
# R2_score of model  GradientBoostingRegressor() is equal =  18.781937591148314
# Cross validation of model  2 is equal =  0.1626960114925936
# Diff between r2_score and cross_validation of model  GradientBoostingRegressor() is equal =  0.025123364418889516
# R2_score of model  AdaBoostRegressor() is equal =  18.34125423189994
# Cross validation of model  2 is equal =  0.14053278797625174
# Diff between r2_score and cross_validation of model  AdaBoostRegressor() is equal =  0.042879754342747656
# ...

# %% [markdown]
# # HYPERTUNING

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters1={'fit_intercept':[False,True],
             'copy_X':[False,True],
             'n_jobs':[1,2],
             'positive':[False,True]}
gscv_lr1=GridSearchCV(estimator=lr1,param_grid=parameters1)
gscv_lr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=LinearRegression(),
#              param_grid={'copy_X': [False, True],
#                          'fit_intercept': [False, True], 'n_jobs': [1, 2],
#                          'positive': [False, True]})

# %%
print((gscv_lr1.best_score_)*1000)
print(gscv_lr1.best_params_)
print(gscv_lr1.best_estimator_)
# Out:
# 77.27823286804029
# {'copy_X': False, 'fit_intercept': True, 'n_jobs': 1, 'positive': False}
# LinearRegression(copy_X=False, n_jobs=1)

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_gbr1=GridSearchCV(estimator=gbr1,param_grid=parameters1)
gscv_gbr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_gbr1.best_score_)
print(gscv_gbr1.best_params_)
print(gscv_gbr1.best_estimator_)
# Out:
# 0.2024966026317836
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 50}
# GradientBoostingRegressor(criterion='squared_error', max_features='sqrt',
#                           n_estimators=50)

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_etr1=GridSearchCV(estimator=etr1,param_grid=parameters1)
gscv_etr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=ExtraTreesRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_etr1.best_score_)
print(gscv_etr1.best_params_)
print(gscv_etr1.best_estimator_)
# Out:
# 0.13084708093658343
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 100}
# ExtraTreesRegressor(max_depth=3, max_features='auto')

# %%
parameters1={'n_estimators':[50,100,150,200],
            'criterion':['gini','squared_error'],
            'max_depth':[1,2,3],
            'max_features':['auto','sqrt','log2']}
gscv_rfr1=GridSearchCV(estimator=rfr1,param_grid=parameters1)
gscv_rfr1.fit(x_train1,y_train1)
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'criterion': ['gini', 'squared_error'],
#                          'max_depth': [1, 2, 3],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [50, 100, 150, 200]})

# %%
print(gscv_rfr1.best_score_)
print(gscv_rfr1.best_params_)
print(gscv_rfr1.best_estimator_)
# Out:
# 0.18739767655595407
# {'criterion': 'squared_error', 'max_depth': 3, 'max_features': 'auto', 'n_estimators': 200}
# RandomForestRegressor(max_depth=3, max_features='auto', n_estimators=200)

# %% [markdown]
# # ROC_CURVE

# %%
from sklearn.metrics import roc_curve,plot_roc_curve

# %%
plt.scatter(predlr1,y_test1)
plt.plot(y_test1,y_test1,linewidth=4,color='Red')

# %% [markdown]
# # Above all methods of testing we find LINEAR REGRESSION to be the most fitted model as it shows more accurate r2_score to predict GROSS_COLLECTION of the dataset movie2 so we are saving it.
#
# # SAVING THE BEST FITTED MODEL

# %%
import pickle
filename='movie2_Gross_collection.pkl'

# %%
pickle.dump(lr1,open(filename,'wb'))

# %% [markdown]
# # LOADING THE SAVED MODEL

# %%
pickle.load(open(filename,'rb'))
# Out:
# LinearRegression()
